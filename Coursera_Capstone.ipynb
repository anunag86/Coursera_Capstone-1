# %% [markdown]
# # MY CAPSTONE PROJECT COURSE

# %% [markdown]
# ### This is a IBM professional course_9
# The Capstone Project focuses on using the skill that learned in the previous courses and use them here.
# #### This notebook is now exclusive used for Capstone Project

# %%
import pandas as pd
import numpy as np

# %%
print("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!
